# %% [markdown]
# Analyzing Ebar Car Sales Data
# ======

# %% [markdown]
# The aim of this project is to clean and analyze the used cars that are listed on Ebay. The dataset is from Kleinanzeigen, a classifieds section of the German eBay website.

# %%
import numpy as np
import pandas as pd

# %%
autos = pd.read_csv("autos.csv", encoding = "Latin1")

# %%
autos
# Out:
#                dateCrawled                                               name  \
# 0      2016-03-26 17:47:46                   Peugeot_807_160_NAVTECH_ON_BOARD
# 1      2016-04-04 13:38:56         BMW_740i_4_4_Liter_HAMANN_UMBAU_Mega_Optik
# 2      2016-03-26 18:57:24                         Volkswagen_Golf_1.6_United
# 3      2016-03-12 16:58:10  Smart_smart_fortwo_coupe_softouch/F1/Klima/Pan...
# 4      2016-04-01 14:38:50  Ford_Focus_1_6_Benzin_TÜV_neu_ist_sehr_gepfleg...
# 5      2016-03-21 13:47:45  Chrysler_Grand_Voyager_2.8_CRD_Aut.Limited_Sto...
# 6      2016-03-20 17:55:21  VW_Golf_III_GT_Special_Electronic_Green_Metall...
# 7      2016-03-16 18:55:19                               Golf_IV_1.9_TDI_90PS
# 8      2016-03-22 16:51:34                                         Seat_Arosa
# 9      2016-03-16 13:47:02          Renault_Megane_Scenic_1.6e_RT_Klimaanlage
# 10     2016-03-15 01:41:36                       VW_Golf_Tuning_in_siber/grau
# ...

# %%
autos.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 50000 entries, 0 to 49999
# Data columns (total 20 columns):
# dateCrawled            50000 non-null object
# name                   50000 non-null object
# seller                 50000 non-null object
# offerType              50000 non-null object
# price                  50000 non-null object
# abtest                 50000 non-null object
# vehicleType            44905 non-null object
# yearOfRegistration     50000 non-null int64
# gearbox                47320 non-null object
# powerPS                50000 non-null int64
# model                  47242 non-null object
# odometer               50000 non-null object
# monthOfRegistration    50000 non-null int64
# fuelType               45518 non-null object
# brand                  50000 non-null object
# notRepairedDamage      40171 non-null object
# dateCreated            50000 non-null object
# nrOfPictures           50000 non-null int64
# ...

# %%
autos.head()
# Out:
#            dateCrawled                                               name  \
# 0  2016-03-26 17:47:46                   Peugeot_807_160_NAVTECH_ON_BOARD
# 1  2016-04-04 13:38:56         BMW_740i_4_4_Liter_HAMANN_UMBAU_Mega_Optik
# 2  2016-03-26 18:57:24                         Volkswagen_Golf_1.6_United
# 3  2016-03-12 16:58:10  Smart_smart_fortwo_coupe_softouch/F1/Klima/Pan...
# 4  2016-04-01 14:38:50  Ford_Focus_1_6_Benzin_TÜV_neu_ist_sehr_gepfleg...
#
#    seller offerType   price   abtest vehicleType  yearOfRegistration  \
# 0  privat   Angebot  $5,000  control         bus                2004
# 1  privat   Angebot  $8,500  control   limousine                1997
# 2  privat   Angebot  $8,990     test   limousine                2009
# 3  privat   Angebot  $4,350  control  kleinwagen                2007
# 4  privat   Angebot  $1,350     test       kombi                2003
#
#      gearbox  powerPS   model   odometer  monthOfRegistration fuelType  \
# ...

# %% [markdown]
# As we can see above, the data is in German and car names are not written in an easy-to-read way. We have a lot of cleaning duties to do. The column name are also written with camelcase, first we need to convert them into snakecase.

# %%
autos.columns
# Out:
# Index(['dateCrawled', 'name', 'seller', 'offerType', 'price', 'abtest',
#        'vehicleType', 'yearOfRegistration', 'gearbox', 'powerPS', 'model',
#        'odometer', 'monthOfRegistration', 'fuelType', 'brand',
#        'notRepairedDamage', 'dateCreated', 'nrOfPictures', 'postalCode',
#        'lastSeen'],
#       dtype='object')

# %%
autos.columns = ['date_crawled', 'name', 'seller', 'offer_type', 'price', 'abtest',
       'vehicle_type', 'registration_year', 'gearbox', 'power_ps', 'model',
       'odometer', 'registration_month', 'fuel_type', 'brand',
       'unrepaired_damage', 'ad_created', 'nr_of_pictures', 'postal_code',
       'last_seen']

# %%
autos.head()
# Out:
#           date_crawled                                               name  \
# 0  2016-03-26 17:47:46                   Peugeot_807_160_NAVTECH_ON_BOARD
# 1  2016-04-04 13:38:56         BMW_740i_4_4_Liter_HAMANN_UMBAU_Mega_Optik
# 2  2016-03-26 18:57:24                         Volkswagen_Golf_1.6_United
# 3  2016-03-12 16:58:10  Smart_smart_fortwo_coupe_softouch/F1/Klima/Pan...
# 4  2016-04-01 14:38:50  Ford_Focus_1_6_Benzin_TÜV_neu_ist_sehr_gepfleg...
#
#    seller offer_type   price   abtest vehicle_type  registration_year  \
# 0  privat    Angebot  $5,000  control          bus               2004
# 1  privat    Angebot  $8,500  control    limousine               1997
# 2  privat    Angebot  $8,990     test    limousine               2009
# 3  privat    Angebot  $4,350  control   kleinwagen               2007
# 4  privat    Angebot  $1,350     test        kombi               2003
#
#      gearbox  power_ps   model   odometer  registration_month fuel_type  \
# ...

# %% [markdown]
# Initial Exploring and Cleaning
# ---

# %%
autos.describe()
# Out:
#        registration_year      power_ps  registration_month  nr_of_pictures  \
# count       50000.000000  50000.000000        50000.000000         50000.0
# mean         2005.073280    116.355920            5.723360             0.0
# std           105.712813    209.216627            3.711984             0.0
# min          1000.000000      0.000000            0.000000             0.0
# 25%          1999.000000     70.000000            3.000000             0.0
# 50%          2003.000000    105.000000            6.000000             0.0
# 75%          2008.000000    150.000000            9.000000             0.0
# max          9999.000000  17700.000000           12.000000             0.0
#
#         postal_code
# count  50000.000000
# mean   50813.627300
# std    25779.747957
# min     1067.000000
# 25%    30451.000000
# 50%    49577.000000
# 75%    71540.000000
# max    99998.000000

# %% [markdown]
# As we can see above, the nr_of_pictures columns doesn't have any valuable data. Also some values shouldn't have decimal places like months, or registration years. Price and odometer datas should also be in here since they are numerical. But first, they need cleaning from text and then we will convert them into numerical data.

# %% [markdown]
# First we will remove $ and comma from the price column.

# %%
autos["price"] = (autos["price"]
                  .str.replace("$","")
                  .str.replace(",","")
                  .astype(int))
autos["price"].unique()
# Out:
# array([ 5000,  8500,  8990, ...,   385, 22200, 16995])

# %% [markdown]
# Next, we will remove km and comma from odometer column values and also change the column name to odometer_km.

# %%
autos["odometer"] = (autos["odometer"]
                             .str.replace("km","")
                             .str.replace(",","")
                             .astype(int)
                             )
autos.rename({"odometer": "odometer_km"}, axis=1, inplace=True)
autos["odometer_km"].head()
# Out:
# 0    150000
# 1    150000
# 2     70000
# 3     70000
# 4    150000
# Name: odometer_km, dtype: int64

# %% [markdown]
# Exploring the Odometer and Price Columns
# ---

# %%
autos["price"].unique().shape
# Out:
# (2357,)

# %%
autos["price"].describe()
# Out:
# count    5.000000e+04
# mean     9.840044e+03
# std      4.811044e+05
# min      0.000000e+00
# 25%      1.100000e+03
# 50%      2.950000e+03
# 75%      7.200000e+03
# max      1.000000e+08
# Name: price, dtype: float64

# %%
autos["price"].value_counts().head()
# Out:
# 0       1421
# 500      781
# 1500     734
# 2500     643
# 1000     639
# Name: price, dtype: int64

# %%
autos["price"].value_counts().sort_index(ascending = True).head(10)
# Out:
# 0     1421
# 1      156
# 2        3
# 3        1
# 5        2
# 8        1
# 9        1
# 10       7
# 11       2
# 12       3
# Name: price, dtype: int64

# %%
autos["price"].value_counts().sort_index(ascending = False).head(10)
# Out:
# 99999999    1
# 27322222    1
# 12345678    3
# 11111111    2
# 10000000    1
# 3890000     1
# 1300000     1
# 1234566     1
# 999999      2
# 999990      1
# Name: price, dtype: int64

# %% [markdown]
# We can see that there are oddly priced car datas like 0, 1 or 99999999. We need to eliminate them.

# %%
autos = autos[autos["price"].between(1,351000)]

# %%
autos["price"].describe()
# Out:
# count     48565.000000
# mean       5888.935591
# std        9059.854754
# min           1.000000
# 25%        1200.000000
# 50%        3000.000000
# 75%        7490.000000
# max      350000.000000
# Name: price, dtype: float64

# %% [markdown]
# We eliminated the outliers in price column, next we will observe  odometer_km column to see if we need to eliminate any kind of odd values.

# %%
autos["odometer_km"].value_counts()
# Out:
# 150000    31414
# 125000     5057
# 100000     2115
# 90000      1734
# 80000      1415
# 70000      1217
# 60000      1155
# 50000      1012
# 5000        836
# 40000       815
# 30000       780
# 20000       762
# 10000       253
# Name: odometer_km, dtype: int64

# %% [markdown]
# It looks like there are no outliers in this column.

# %%
autos["odometer_km"].describe()
# Out:
# count     48565.000000
# mean     125770.101925
# std       39788.636804
# min        5000.000000
# 25%      125000.000000
# 50%      150000.000000
# 75%      150000.000000
# max      150000.000000
# Name: odometer_km, dtype: float64

# %% [markdown]
# Exploring Date Columns
# ---

# %% [markdown]
# To understand the date range, we will extract just the date values.

# %%
autos[['date_crawled','ad_created','last_seen']][0:5]
# Out:
#           date_crawled           ad_created            last_seen
# 0  2016-03-26 17:47:46  2016-03-26 00:00:00  2016-04-06 06:45:54
# 1  2016-04-04 13:38:56  2016-04-04 00:00:00  2016-04-06 14:45:08
# 2  2016-03-26 18:57:24  2016-03-26 00:00:00  2016-04-06 20:15:37
# 3  2016-03-12 16:58:10  2016-03-12 00:00:00  2016-03-15 03:16:28
# 4  2016-04-01 14:38:50  2016-04-01 00:00:00  2016-04-01 14:38:50

# %%
autos["date_crawled"].value_counts().head()
# Out:
# 2016-03-29 23:42:13    3
# 2016-03-11 22:38:16    3
# 2016-03-16 21:50:53    3
# 2016-03-22 09:51:06    3
# 2016-03-09 11:54:38    3
# Name: date_crawled, dtype: int64

# %%
autos["date_crawled"].str[:10].unique().shape
# Out:
# (34,)

# %%
#Sorting by date

# %%
(autos["date_crawled"]
 .str[:10]
 .value_counts(normalize=True, dropna=False)
 .sort_index())
# Out:
# 2016-03-05    0.025327
# 2016-03-06    0.014043
# 2016-03-07    0.036014
# 2016-03-08    0.033296
# 2016-03-09    0.033090
# 2016-03-10    0.032184
# 2016-03-11    0.032575
# 2016-03-12    0.036920
# 2016-03-13    0.015670
# 2016-03-14    0.036549
# 2016-03-15    0.034284
# 2016-03-16    0.029610
# 2016-03-17    0.031628
# 2016-03-18    0.012911
# 2016-03-19    0.034778
# 2016-03-20    0.037887
# 2016-03-21    0.037373
# 2016-03-22    0.032987
# 2016-03-23    0.032225
# 2016-03-24    0.029342
# 2016-03-25    0.031607
# 2016-03-26    0.032204
# 2016-03-27    0.031092
# 2016-03-28    0.034860
# 2016-03-29    0.034099
# 2016-03-30    0.033687
# 2016-03-31    0.031834
# 2016-04-01    0.033687
# 2016-04-02    0.035478
# 2016-04-03    0.038608
# 2016-04-04    0.036487
# 2016-04-05    0.013096
# 2016-04-06    0.003171
# 2016-04-07    0.001400
# Name: date_crawled, dtype: float64

# %%
#Sorting by percentage

# %%
(autos["date_crawled"]
 .str[:10]
 .value_counts(normalize=True, dropna=False)
 .sort_values())
# Out:
# 2016-04-07    0.001400
# 2016-04-06    0.003171
# 2016-03-18    0.012911
# 2016-04-05    0.013096
# 2016-03-06    0.014043
# 2016-03-13    0.015670
# 2016-03-05    0.025327
# 2016-03-24    0.029342
# 2016-03-16    0.029610
# 2016-03-27    0.031092
# 2016-03-25    0.031607
# 2016-03-17    0.031628
# 2016-03-31    0.031834
# 2016-03-10    0.032184
# 2016-03-26    0.032204
# 2016-03-23    0.032225
# 2016-03-11    0.032575
# 2016-03-22    0.032987
# 2016-03-09    0.033090
# 2016-03-08    0.033296
# 2016-03-30    0.033687
# 2016-04-01    0.033687
# 2016-03-29    0.034099
# 2016-03-15    0.034284
# 2016-03-19    0.034778
# 2016-03-28    0.034860
# 2016-04-02    0.035478
# 2016-03-07    0.036014
# 2016-04-04    0.036487
# 2016-03-14    0.036549
# 2016-03-12    0.036920
# 2016-03-21    0.037373
# 2016-03-20    0.037887
# 2016-04-03    0.038608
# Name: date_crawled, dtype: float64

# %% [markdown]
# As we can see from the percentages and date range, the distribution is roughly uniform. The date range is in between March 2016 and April 2016. The percentage range is between %0.14 and %3.9

# %% [markdown]
# Next, we will do the same exploration with ad_created, last_seen and registration_year columns.

# %%
autos["ad_created"].str[:10].value_counts().head()
# Out:
# 2016-04-03    1887
# 2016-03-20    1843
# 2016-03-21    1825
# 2016-04-04    1790
# 2016-03-12    1785
# Name: ad_created, dtype: int64

# %%
autos["ad_created"].str[:10].unique().shape
# Out:
# (76,)

# %%
(autos["ad_created"]
 .str[:10]
 .value_counts(normalize=True, dropna=False)
 .sort_index())
# Out:
# 2015-06-11    0.000021
# 2015-08-10    0.000021
# 2015-09-09    0.000021
# 2015-11-10    0.000021
# 2015-12-05    0.000021
# 2015-12-30    0.000021
# 2016-01-03    0.000021
# 2016-01-07    0.000021
# 2016-01-10    0.000041
# 2016-01-13    0.000021
# 2016-01-14    0.000021
# 2016-01-16    0.000021
# 2016-01-22    0.000021
# 2016-01-27    0.000062
# 2016-01-29    0.000021
# 2016-02-01    0.000021
# 2016-02-02    0.000041
# 2016-02-05    0.000041
# 2016-02-07    0.000021
# 2016-02-08    0.000021
# 2016-02-09    0.000021
# 2016-02-11    0.000021
# 2016-02-12    0.000041
# 2016-02-14    0.000041
# 2016-02-16    0.000021
# 2016-02-17    0.000021
# 2016-02-18    0.000041
# 2016-02-19    0.000062
# 2016-02-20    0.000041
# 2016-02-21    0.000062
#                 ...
# 2016-03-09    0.033151
# 2016-03-10    0.031895
# 2016-03-11    0.032904
# 2016-03-12    0.036755
# 2016-03-13    0.017008
# 2016-03-14    0.035190
# 2016-03-15    0.034016
# 2016-03-16    0.030125
# 2016-03-17    0.031278
# ...

# %%
(autos["ad_created"]
 .str[:10]
 .value_counts(normalize=True, dropna=False)
 .sort_values())
# Out:
# 2015-09-09    0.000021
# 2016-01-16    0.000021
# 2016-01-07    0.000021
# 2016-01-03    0.000021
# 2016-01-13    0.000021
# 2015-06-11    0.000021
# 2016-02-11    0.000021
# 2016-02-09    0.000021
# 2016-01-29    0.000021
# 2015-08-10    0.000021
# 2016-02-08    0.000021
# 2015-12-05    0.000021
# 2016-01-14    0.000021
# 2015-11-10    0.000021
# 2016-02-22    0.000021
# 2016-02-16    0.000021
# 2016-02-07    0.000021
# 2015-12-30    0.000021
# 2016-02-01    0.000021
# 2016-02-17    0.000021
# 2016-01-22    0.000021
# 2016-02-18    0.000041
# 2016-01-10    0.000041
# 2016-02-14    0.000041
# 2016-02-12    0.000041
# 2016-02-26    0.000041
# 2016-02-20    0.000041
# 2016-02-05    0.000041
# 2016-02-24    0.000041
# 2016-02-02    0.000041
#                 ...
# 2016-03-06    0.015320
# 2016-03-13    0.017008
# 2016-03-05    0.022897
# 2016-03-24    0.029280
# 2016-03-16    0.030125
# 2016-03-27    0.030989
# 2016-03-17    0.031278
# 2016-03-25    0.031751
# 2016-03-31    0.031875
# ...

# %% [markdown]
# The date range is in between mid November 2015 and mid April 2016 so the range is higher. However, most dates fall within February 2016 and April 2016. The percentage range is also higher with minimum value %0.002 and maximum value %3.9. Therefore, ad_created data is not uniform.

# %% [markdown]
# Now let's look at last_seen columns.

# %%
(autos["last_seen"].
 str[:10].
 value_counts(normalize=True, dropna=False)
.sort_index())
# Out:
# 2016-03-05    0.001071
# 2016-03-06    0.004324
# 2016-03-07    0.005395
# 2016-03-08    0.007413
# 2016-03-09    0.009595
# 2016-03-10    0.010666
# 2016-03-11    0.012375
# 2016-03-12    0.023783
# 2016-03-13    0.008895
# 2016-03-14    0.012602
# 2016-03-15    0.015876
# 2016-03-16    0.016452
# 2016-03-17    0.028086
# 2016-03-18    0.007351
# 2016-03-19    0.015834
# 2016-03-20    0.020653
# 2016-03-21    0.020632
# 2016-03-22    0.021373
# 2016-03-23    0.018532
# 2016-03-24    0.019767
# 2016-03-25    0.019211
# 2016-03-26    0.016802
# 2016-03-27    0.015649
# 2016-03-28    0.020859
# 2016-03-29    0.022341
# 2016-03-30    0.024771
# 2016-03-31    0.023783
# 2016-04-01    0.022794
# 2016-04-02    0.024915
# 2016-04-03    0.025203
# 2016-04-04    0.024483
# 2016-04-05    0.124761
# 2016-04-06    0.221806
# 2016-04-07    0.131947
# Name: last_seen, dtype: float64

# %%
(autos["last_seen"].
 str[:10].
 value_counts(normalize=True, dropna=False)
.sort_values())
# Out:
# 2016-03-05    0.001071
# 2016-03-06    0.004324
# 2016-03-07    0.005395
# 2016-03-18    0.007351
# 2016-03-08    0.007413
# 2016-03-13    0.008895
# 2016-03-09    0.009595
# 2016-03-10    0.010666
# 2016-03-11    0.012375
# 2016-03-14    0.012602
# 2016-03-27    0.015649
# 2016-03-19    0.015834
# 2016-03-15    0.015876
# 2016-03-16    0.016452
# 2016-03-26    0.016802
# 2016-03-23    0.018532
# 2016-03-25    0.019211
# 2016-03-24    0.019767
# 2016-03-21    0.020632
# 2016-03-20    0.020653
# 2016-03-28    0.020859
# 2016-03-22    0.021373
# 2016-03-29    0.022341
# 2016-04-01    0.022794
# 2016-03-31    0.023783
# 2016-03-12    0.023783
# 2016-04-04    0.024483
# 2016-03-30    0.024771
# 2016-04-02    0.024915
# 2016-04-03    0.025203
# 2016-03-17    0.028086
# 2016-04-05    0.124761
# 2016-04-07    0.131947
# 2016-04-06    0.221806
# Name: last_seen, dtype: float64

# %% [markdown]
# For last_seen column, the distribution is roughly uniform for the date range. It is in between March 2016 and April 2016. The percentage range is between %0.1 and %22.2. On the last three days, the percentage is very high, so there is likely to be a mistake in here.

# %% [markdown]
# Dealing with Incorrect Registration Year Data
# ---

# %%
autos["registration_year"].describe()
# Out:
# count    48565.000000
# mean      2004.755421
# std         88.643887
# min       1000.000000
# 25%       1999.000000
# 50%       2004.000000
# 75%       2008.000000
# max       9999.000000
# Name: registration_year, dtype: float64

# %% [markdown]
# The minimum registration year is 1000 which is an odd value, many years before the cars were invented, and the maximum year is 9999 which is many years ahead from today.

# %% [markdown]
# We need to clear some data that fall outside of the years 1900-2016.

# %%
autos["registration_year"].value_counts(normalize=True).sort_index()
# Out:
# 1000    0.000021
# 1001    0.000021
# 1111    0.000021
# 1800    0.000041
# 1910    0.000103
# 1927    0.000021
# 1929    0.000021
# 1931    0.000021
# 1934    0.000041
# 1937    0.000082
# 1938    0.000021
# 1939    0.000021
# 1941    0.000041
# 1943    0.000021
# 1948    0.000021
# 1950    0.000062
# 1951    0.000041
# 1952    0.000021
# 1953    0.000021
# 1954    0.000041
# 1955    0.000041
# 1956    0.000082
# 1957    0.000041
# 1958    0.000082
# 1959    0.000124
# 1960    0.000474
# 1961    0.000124
# 1962    0.000082
# 1963    0.000165
# 1964    0.000247
#           ...
# 2000    0.064985
# 2001    0.054278
# 2002    0.051189
# 2003    0.055575
# 2004    0.055657
# 2005    0.060455
# 2006    0.054978
# 2007    0.046886
# 2008    0.045609
# 2009    0.042932
# 2010    0.032719
# 2011    0.033419
# 2012    0.026974
# 2013    0.016535
# 2014    0.013652
# 2015    0.008072
# 2016    0.025121
# 2017    0.028663
# 2018    0.009678
# 2019    0.000041
# 2800    0.000021
# ...

# %%
(autos["registration_year"].between(1900,2016).sum())/autos.shape[0]
# Out:
# 0.961206630289303

# %% [markdown]
# The percentage of the cars that are inside the range of 1900 and 2016 is 96.1%.

# %%
(~autos["registration_year"].between(1900,2016)).sum() / autos.shape[0]
# Out:
# 0.038793369710697

# %% [markdown]
# The percentage of the car that are outside of our range is 3.9%. Therefore we will remove this data.

# %%
autos = autos[autos["registration_year"].between(1900,2016)]

# %%
autos["registration_year"].value_counts(normalize=True).head(10)
# Out:
# 2000    0.067608
# 2005    0.062895
# 1999    0.062060
# 2004    0.057904
# 2003    0.057818
# 2006    0.057197
# 2001    0.056468
# 2002    0.053255
# 1998    0.050620
# 2007    0.048778
# Name: registration_year, dtype: float64

# %%
(autos["registration_year"]
 .value_counts(normalize=True)
 .sort_values(ascending = False)
 .head(20))
# Out:
# 2000    0.067608
# 2005    0.062895
# 1999    0.062060
# 2004    0.057904
# 2003    0.057818
# 2006    0.057197
# 2001    0.056468
# 2002    0.053255
# 1998    0.050620
# 2007    0.048778
# 2008    0.047450
# 2009    0.044665
# 1997    0.041794
# 2011    0.034768
# 2010    0.034040
# 1996    0.029412
# 2012    0.028063
# 1995    0.026285
# 2016    0.026135
# 2013    0.017202
# Name: registration_year, dtype: float64

# %% [markdown]
# We sorted the registration years by their percentages. We can see that the most of the cars were registered in the past 20 years.

# %% [markdown]
# Exploring Price by Brand
# ---

# %% [markdown]
# Now let's explore the brand column.

# %%
autos["brand"].unique()
# Out:
# array(['peugeot', 'bmw', 'volkswagen', 'smart', 'ford', 'chrysler',
#        'seat', 'renault', 'mercedes_benz', 'audi', 'sonstige_autos',
#        'opel', 'mazda', 'porsche', 'mini', 'toyota', 'dacia', 'nissan',
#        'jeep', 'saab', 'volvo', 'mitsubishi', 'jaguar', 'fiat', 'skoda',
#        'subaru', 'kia', 'citroen', 'chevrolet', 'hyundai', 'honda',
#        'daewoo', 'suzuki', 'trabant', 'land_rover', 'alfa_romeo', 'lada',
#        'rover', 'daihatsu', 'lancia'], dtype=object)

# %%
(autos["brand"]
 .value_counts(normalize=True)
 .head(10)
 .sort_values(ascending=False))
# Out:
# volkswagen       0.211264
# bmw              0.110045
# opel             0.107581
# mercedes_benz    0.096463
# audi             0.086566
# ford             0.069900
# renault          0.047150
# peugeot          0.029841
# fiat             0.025642
# seat             0.018273
# Name: brand, dtype: float64

# %%
brand_names = autos["brand"].value_counts().head(10).index

# %%
brand_names
# Out:
# Index(['volkswagen', 'bmw', 'opel', 'mercedes_benz', 'audi', 'ford', 'renault',
#        'peugeot', 'fiat', 'seat'],
#       dtype='object')

# %% [markdown]
# We will continue our analysis with these top 10 brands since they are the most common brands on our dataset.

# %%
brand_prices = {}

for i in brand_names:
    name = autos[autos["brand"] == i]
    mean_price = name["price"].mean()
    brand_prices[i] = int(mean_price)

# %%
brand_prices
# Out:
# {'audi': 9336,
#  'bmw': 8332,
#  'fiat': 2813,
#  'ford': 3749,
#  'mercedes_benz': 8628,
#  'opel': 2975,
#  'peugeot': 3094,
#  'renault': 2474,
#  'seat': 4397,
#  'volkswagen': 5402}

# %% [markdown]
# It looks like Audi, BMW, Mercedes-Benz have the highest prices, Volkswagen is in between, and others have lower prices.

# %% [markdown]
# Next, we will calculate the mean milage for these brands.

# %%
brand_milage = {}

for i in brand_names:
    name = autos[autos["brand"] == i]
    mean_milage = name["odometer_km"].mean()
    brand_milage[i] = int(mean_milage)
    
brand_milage
# Out:
# {'audi': 129157,
#  'bmw': 132572,
#  'fiat': 117121,
#  'ford': 124266,
#  'mercedes_benz': 130788,
#  'opel': 129310,
#  'peugeot': 127153,
#  'renault': 128071,
#  'seat': 121131,
#  'volkswagen': 128707}

# %% [markdown]
# It looks like on average, there are not much milage differences between the car brands.

# %% [markdown]
# Storing Aggregate Data in a DataFrame
# ---

# %% [markdown]
# Next, we will convert the two dictionaries into pandas series.

# %%
brand_p = pd.Series(brand_prices)

# %%
brand_m = pd.Series(brand_milage)

# %%
df_price_milage = pd.DataFrame(brand_p, columns = ["mean_price"])

# %%
df_price_milage["mean_milage"] = brand_m

# %%
df_price_milage
# Out:
#                mean_price  mean_milage
# audi                 9336       129157
# bmw                  8332       132572
# fiat                 2813       117121
# ford                 3749       124266
# mercedes_benz        8628       130788
# opel                 2975       129310
# peugeot              3094       127153
# renault              2474       128071
# seat                 4397       121131
# volkswagen           5402       128707

# %% [markdown]
# As we can see on our dataframe, the brand affects the average price, but the average milage, doesn't affect the prices of the cars.
# For example, Opel has 129310 milage on average and Audi has 129157 milage on average. The values are almost the same, however there is a huge price gap between these two brands.
